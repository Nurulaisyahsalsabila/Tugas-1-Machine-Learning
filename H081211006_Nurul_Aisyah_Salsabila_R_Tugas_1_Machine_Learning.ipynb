# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurulaisyahsalsabila/Tugas-1-Machine-Learning/blob/main/H081211006_Nurul_Aisyah_Salsabila_R_Tugas_1_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/apple_quality.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
data.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
print(data.dtypes)
# Out:
# A_id           float64
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity         object
# Quality         object
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#         A_id      Size    Weight  Sweetness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658   3.030874 -1.303849
# ...      ...       ...       ...        ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# ...

# %%
data.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
data.loc[:,"Size":].corr()
# Out:
# <ipython-input-11-c5f5eaa000f9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Size":].corr()
#                  Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# Size         1.000000 -0.170702  -0.324680     0.169868  -0.018892 -0.134773
# Weight      -0.170702  1.000000  -0.154246    -0.095882  -0.092263 -0.243824
# Sweetness   -0.324680 -0.154246   1.000000    -0.037552   0.095882 -0.273800
# Crunchiness  0.169868 -0.095882  -0.037552     1.000000  -0.259607 -0.201982
# Juiciness   -0.018892 -0.092263   0.095882    -0.259607   1.000000 -0.097144
# Ripeness    -0.134773 -0.243824  -0.273800    -0.201982  -0.097144  1.000000

# %%
# @title Size vs Sweetness

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Size', y='Sweetness', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c0c7ba6f-b725-4c67-b8bd-f0d1a9dab5c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0c7ba6f-b725-4c67-b8bd-f0d1a9dab5c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "house price"
# Out:
# ...
# ref                                                     title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# juhibhojani/house-price                                 House Price                                           7MB  2023-08-02 16:51:21           5143         80  0.9411765
# shree1992/housedata                                     House price prediction                              432KB  2018-08-26 07:56:22          71403        579  0.64705884
# anmolkumar/house-price-prediction-challenge             House Price Prediction Challenge                      2MB  2020-10-01 19:37:13          18417        217  1.0
# ...

# %%
# !kaggle datasets download juhibhojani/house-price
# Out:
# ...
#  61% 4.00M/6.61M [00:00<00:00, 6.36MB/s]
# 100% 6.61M/6.61M [00:00<00:00, 6.95MB/s]

# %%
# !unzip /content/house-price.zip
# Out:
# Archive:  /content/house-price.zip
#   inflating: house_prices.csv

# %%
pd.read_csv('/content/house_prices.csv')
# Out:
#          Index                                              Title  \
# 0            0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1            1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2            2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3            3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4            4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
# ...        ...                                                ...
# 187526  187526  3 BHK Ready to Occupy Flat for sale in Bollywo...
# 187527  187527  3 BHK Ready to Occupy Flat for sale in Sushma ...
# 187528  187528  3 BHK Ready to Occupy Flat for sale in Bollywo...
# 187529  187529  2 BHK Ready to Occupy Flat for sale in Friends...
# 187530  187530  3 BHK Ready to Occupy Flat for sale in Affinit...
#
#                                               Description Amount(in rupees)  \
# 0       Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# ...
